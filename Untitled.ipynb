# %%
pwd
# Out:
# 'C:\\Users\\rkustas\\OneDrive - ogg.com\\DU_class\\Project-2'

# %%
path = "Healthcare_trends/US_PER_CAPITA14.CSV"

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(path)
data
# Out:
#      Code                                              Item          Group  \
# 0       1                          Personal Health Care ($)  United States
# 1       1                          Personal Health Care ($)         Region
# 2       1                          Personal Health Care ($)         Region
# 3       1                          Personal Health Care ($)         Region
# 4       1                          Personal Health Care ($)         Region
# 5       1                          Personal Health Care ($)         Region
# 6       1                          Personal Health Care ($)         Region
# 7       1                          Personal Health Care ($)         Region
# 8       1                          Personal Health Care ($)         Region
# 9       1                          Personal Health Care ($)          State
# 10      1                          Personal Health Care ($)          State
# ...

# %%
us = data['Region_Name'] == "United States"
data[us]
# Out:
#      Code                                               Item          Group  \
# 0       1                           Personal Health Care ($)  United States
# 60      2                                  Hospital Care ($)  United States
# 120     3                  Physician & Clinical Services ($)  United States
# 180     4                    Other Professional Services ($)  United States
# 240     5                                Dental Services ($)  United States
# 300     6                               Home Health Care ($)  United States
# 360     7  Prescription Drugs and Other Non-durable Medic...  United States
# 420     8                       Durable Medical Products ($)  United States
# 480     9                              Nursing Home Care ($)  United States
# 540    10   Other Health, Residential, and Personal Care ($)  United States
#
#      Region_Number    Region_Name State_Name  Y1991  Y1992  Y1993  Y1994  ...  \
# ...
